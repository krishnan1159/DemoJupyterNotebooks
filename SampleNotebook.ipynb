# %% [markdown]
# # Demo Notebook
# This is a sample Jupyter notebook.

# %%
a = 1 + 2
print(a)
# Out:
# 3

# %% [markdown]
# ## Numpy Example
# Demonstrate a basic NumPy operation.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np

p = np.linspace(0, 1, 1000)
prob_win = (p ** 7) * ((1 - p) ** 3)

# Derivative zeros at p = 0, 0.7, 1
p_critical = 0.7
prob_critical = (p_critical ** 7) * ((1 - p_critical) ** 3)

plt.plot(p, prob_win, label='Probability of Winning')

# Mark the critical point p=0.7
plt.scatter(p_critical, prob_critical, color='red', zorder=5)
plt.annotate(f'Max at p={p_critical:.2f}\nProb={prob_critical:.4f}',
             xy=(p_critical, prob_critical),
             xytext=(p_critical+0.05, prob_critical),
             arrowprops=dict(facecolor='black', shrink=0.05))

plt.title('Probability of Winning vs Coin Fairness')
plt.xlabel('Fairness of Coin (Probability of Heads)')
plt.ylabel('Probability of Winning (7 heads followed by 3 tails)')
plt.grid(True)

plt.legend()
plt.show()
